# %% [markdown]
# # <center><u>Efficient Yelp API Calls (Core)</u>
# * Authored By: Eric N. Valdez
# * Date: 1/22/2024

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# additional imports
import json, os, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

#progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (2.5.1)
# Requirement already satisfied: requests in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2023.5.7)
# Requirement already satisfied: tqdm in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\valde\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.6)

# %% [markdown]
# ## <u>Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open ('/Users/Valde/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# login.items()
# login['api-key']
# Out:
# 'sAM-z6jxwvNnaowWcZeLz55gNMgXaLor4PpDJQ_wmeid29pENW6sAoT-agduSnu8ylcW5WGw4VTjWCnjjAK2YPHA2dMr2hOPbv3PmT4Rmgy2n7Xf5Cd5LpyPd1tAZXYx'

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
# ## <u>Define Search Term and File Paths

# %%
# Set our API call Parameters and filename before the first call
location = 'Phillips Ranch, CA 91766'
term = 'sushi'

# %%
location.split(',') [0]
# Out:
# 'Phillips Ranch'

# %%
# Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Phillips Ranch-sushi.json'

# %% [markdown]
# ## <u>Check if Json File exists and Create it if it doesn't

# %%
# Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

# If it does not exist: 
if file_exists == False:
    
    # CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    # If JSON_FILE included a folder:
    if len(folder)>0:
        # Create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    # INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    # save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
# If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Phillips Ranch-sushi.json already exists.

# %% [markdown]
# ## <u>Load JSON_FILE and account for previous resultstime?

# %% [markdown]
# ### Make the first API call to get the first page of data
# * We will use this first result to check:
#     * How many total results there are?
#     * Where is the actual data we want to save?
#     * How many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 548

# %%
results['region']
# Out:
# {'center': {'longitude': -117.74734497070312, 'latitude': 34.061718406896176}}

# %%
results['businesses']
# Out:
# [{'id': 'JlN5BhjbErkp6myx-8Adkw',
#   'alias': 'kazama-sushi-claremont',
#   'name': 'Kazama Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Rl8QJx9lKwOdXI1j-2AemQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kazama-sushi-claremont?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 1482,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.095166, 'longitude': -117.719514},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '101 N Indian Hill Blvd',
#    'address2': 'Ste C1-104',
#    'address3': '',
#    'city': 'Claremont',
#    'zip_code': '91711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['101 N Indian Hill Blvd',
#     'Ste C1-104',
#     'Claremont, CA 91711']},
#   'phone': '+19094502505',
#   'display_phone': '(909) 450-2505',
#   'distance': 4516.914865334514},
#  {'id': 'eh26nTBs70zvxlL8mFOq6g',
#   'alias': 'roll-to-go-sushi-pomona-3',
#   'name': 'Roll To Go Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dVd3sWu_PiVhLhSHFWYwrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roll-to-go-sushi-pomona-3?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 2,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 34.06199689430613, 'longitude': -117.7381829},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '642 E Holt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Pomona',
#    'zip_code': '91767',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['642 E Holt Ave', 'Pomona, CA 91767']},
#   'phone': '+16264782188',
#   'display_phone': '(626) 478-2188',
#   'distance': 844.5548154245203},
#  {'id': 'v4mgrnnrqMCCEyLnzd5tgw',
#   'alias': 'spicy-fish-pomona-2',
#   'name': 'Spicy Fish',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3-fr-k9GLL9OoOsOKdA51w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spicy-fish-pomona-2?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 160,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.05437, 'longitude': -117.76271},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1084 W Mission Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Pomona',
#    'zip_code': '91766',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1084 W Mission Blvd', 'Pomona, CA 91766']},
#   'phone': '+19097668254',
#   'display_phone': '(909) 766-8254',
#   'distance': 1634.3693369128027},
#  {'id': 'n49shr4AyXEdZHwrM-kjgQ',
#   'alias': 'kisetsu-restaurant-claremont',
#   'name': 'Kisetsu Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8hhBo3kGGMy2F5UEIce3bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kisetsu-restaurant-claremont?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 68,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1063217, 'longitude': -117.7329161},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '950 W Foothill Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Claremont',
#    'zip_code': '91711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['950 W Foothill Blvd', 'Claremont, CA 91711']},
#   'phone': '+19096256250',
#   'display_phone': '(909) 625-6250',
#   'distance': 5134.5779396278385},
#  {'id': 'KCsnVV2LkHqNV7wu5r4FZw',
#   'alias': 'heemo-sushi-chino-hills-chino-hills',
#   'name': 'Heemo Sushi-Chino Hills',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hYBwPVjJlogsIhqSOV90Eg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/heemo-sushi-chino-hills-chino-hills?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 159,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.01625920335954, 'longitude': -117.7453792},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '12959 Peyton Dr',
#    'address2': None,
#    'address3': '',
#    'city': 'Chino Hills',
#    'zip_code': '91709',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['12959 Peyton Dr', 'Chino Hills, CA 91709']},
#   'phone': '+19092229331',
#   'display_phone': '(909) 222-9331',
#   'distance': 5058.0714024692625},
#  {'id': 'ySzi-7ZESSMMteQQmHXHDA',
#   'alias': 'kaya-asian-cuisine-pomona',
#   'name': 'Kaya Asian Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n43zuliuv2I2I4MnbtUFHQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kaya-asian-cuisine-pomona?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 358,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.05398, 'longitude': -117.77543},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1640 W Mission Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Pomona',
#    'zip_code': '91766',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1640 W Mission Blvd', 'Pomona, CA 91766']},
#   'phone': '+19096222689',
#   'display_phone': '(909) 622-2689',
#   'distance': 2859.324205297093},
#  {'id': 'NjgpL_T9TmEHxWVv2-RH5A',
#   'alias': 'culichi-roll-pomona-3',
#   'name': 'Culichi Roll',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3joqVyhY1LQHiZCH8hzhYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/culichi-roll-pomona-3?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 272,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.06270300956817, 'longitude': -117.74847},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '171 E Holt Ave',
#    'address2': 'Ste 102-B',
#    'address3': '',
#    'city': 'Pomona',
#    'zip_code': '91767',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['171 E Holt Ave', 'Ste 102-B', 'Pomona, CA 91767']},
#   'phone': '+19097668006',
#   'display_phone': '(909) 766-8006',
#   'distance': 150.75330381608532},
#  {'id': '4JWqfEnsDsRS3BeH0uyliw',
#   'alias': 'sushi-one-spot-montclair-3',
#   'name': 'Sushi One Spot',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fKiaLMKuDK3eE5H4B2OKDw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-one-spot-montclair-3?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 306,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.083119, 'longitude': -117.696473},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '9405 Monte Vista Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Montclair',
#    'zip_code': '91763',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['9405 Monte Vista Ave', 'Montclair, CA 91763']},
#   'phone': '+19096260070',
#   'display_phone': '(909) 626-0070',
#   'distance': 5255.515529683603},
#  {'id': 'CxVU-Pap9AVkHTSZGPOlAQ',
#   'alias': 'senor-sushi-pomona-2',
#   'name': 'Senor Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_AVDH_Nb0YRnbJoxRvR8DA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/senor-sushi-pomona-2?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 114,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0553180510785,
#    'longitude': -117.750426493585},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '101 W Mission Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Pomona',
#    'zip_code': '91766',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['101 W Mission Blvd', 'Pomona, CA 91766']},
#   'phone': '+19094616412',
#   'display_phone': '(909) 461-6412',
#   'distance': 766.2124142030534},
#  {'id': 'bM61lLChoc5_5x2gyWXu4Q',
#   'alias': 'oni-sushi-claremont-2',
#   'name': 'Oni Sushi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uy9dxSvImVz_pSEBqfXPMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oni-sushi-claremont-2?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 328,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.09686, 'longitude': -117.71889},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '300 N Indian Hill Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Claremont',
#    'zip_code': '91711',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['300 N Indian Hill Blvd', 'Claremont, CA 91711']},
#   'phone': '+19096212772',
#   'display_phone': '(909) 621-2772',
#   'distance': 4686.277205134085},
#  {'id': '5zqyjooZCmGJyYskNXlzhg',
#   'alias': 'makomae-japanese-cuisine-diamond-bar',
#   'name': 'Makomae Japanese Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i9zO9ng24ADDj-4JLplryQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/makomae-japanese-cuisine-diamond-bar?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 681,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.0344545348774,
#    'longitude': -117.805974933914},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '868 N Diamond Bar Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Diamond Bar',
#    'zip_code': '91765',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['868 N Diamond Bar Blvd', 'Diamond Bar, CA 91765']},
#   'phone': '+19098616537',
#   'display_phone': '(909) 861-6537',
#   'distance': 6194.288135474502},
#  {'id': '2C1-2Mj0xINqrtJQodq8OA',
#   'alias': 'show-sushi-san-dimas',
#   'name': 'Show Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ieaNBSZgsiK9j5PPRfre7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/show-sushi-san-dimas?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 2509,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.108007, 'longitude': -117.826514},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '957 W Arrow Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'San Dimas',
#    'zip_code': '91773',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['957 W Arrow Hwy', 'San Dimas, CA 91773']},
#   'phone': '+19095922911',
#   'display_phone': '(909) 592-2911',
#   'distance': 8924.625167596621},
#  {'id': '8nTMRFSXn-NEu1NVAtRYiw',
#   'alias': 'j-sushi-and-ramen-pomona',
#   'name': 'J Sushi & Ramen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TuFKc3IuHbLoUrW_P_9VmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/j-sushi-and-ramen-pomona?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 330,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0280844704734,
#    'longitude': -117.759815566242},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '18 Rancho Camino Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Pomona',
#    'zip_code': '91766',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['18 Rancho Camino Dr', 'Pomona, CA 91766']},
#   'phone': '+19096228700',
#   'display_phone': '(909) 622-8700',
#   'distance': 3912.4379826679087},
#  {'id': 'Q5T7a_J09YX9IDOfcbGQlA',
#   'alias': 'sushiya-san-dimas-2',
#   'name': 'Sushiya',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V3qP3742EF8n7AfJ7-jgdA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushiya-san-dimas-2?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 258,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.10626, 'longitude': -117.81734},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '536 W Bonita Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'San Dimas',
#    'zip_code': '91773',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['536 W Bonita Ave', 'San Dimas, CA 91773']},
#   'phone': '+19095997833',
#   'display_phone': '(909) 599-7833',
#   'distance': 8127.811177296114},
#  {'id': 'rxjJptHauUqFOZ4DWNmIZw',
#   'alias': 'kaiba-japanese-ramen-sushi-and-grill-la-verne-la-verne',
#   'name': 'Kaiba Japanese Ramen, Sushi & Grill - La Verne',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2o54yYO1_Bp20ruKIAs60Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kaiba-japanese-ramen-sushi-and-grill-la-verne-la-verne?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 79,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.118826, 'longitude': -117.779561},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1263 Foothill Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'La Verne',
#    'zip_code': '91750',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1263 Foothill Blvd', 'La Verne, CA 91750']},
#   'phone': '+19095961111',
#   'display_phone': '(909) 596-1111',
#   'distance': 7007.803149021593},
#  {'id': 'u7QaCKPng22AsU3-w1qBgg',
#   'alias': 'sake-2-me-sushi-montclair',
#   'name': 'Sake 2 Me Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tn_eVwxM6qjDpDHGjIMGSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sake-2-me-sushi-montclair?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 1404,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.063599, 'longitude': -117.681654},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5660 Holt Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Montclair',
#    'zip_code': '91763',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5660 Holt Blvd', 'Montclair, CA 91763']},
#   'phone': '+19096260113',
#   'display_phone': '(909) 626-0113',
#   'distance': 6054.841838738033},
#  {'id': 'eKoLScfI41H7XmLXTDczPQ',
#   'alias': 'imari-upland',
#   'name': 'Imari',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1Ia_Qi7tkLq17nrq2Fl36g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/imari-upland?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 262,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 34.10765815493825, 'longitude': -117.6600843},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '733 W Foothill Blvd',
#    'address2': 'Ste D',
#    'address3': '',
#    'city': 'Upland',
#    'zip_code': '91786',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['733 W Foothill Blvd', 'Ste D', 'Upland, CA 91786']},
#   'phone': '+19099311975',
#   'display_phone': '(909) 931-1975',
#   'distance': 9522.221468636813},
#  {'id': 'cGRckOqyiJAPywwyCRwNOA',
#   'alias': 'rumble-fish-sushi-montclair',
#   'name': 'Rumble Fish Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dQXQkRIuOeHCol01QDruig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rumble-fish-sushi-montclair?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 1166,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0888649, 'longitude': -117.6857916},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5470 Moreno St',
#    'address2': 'Ste B',
#    'address3': '',
#    'city': 'Montclair',
#    'zip_code': '91763',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5470 Moreno St', 'Ste B', 'Montclair, CA 91763']},
#   'phone': '+19099461119',
#   'display_phone': '(909) 946-1119',
#   'distance': 6480.223081687656},
#  {'id': 'MyIvDxYoDwlIn8Nd_Fmp5w',
#   'alias': 'all-that-sushi-chino-hills-2',
#   'name': 'All That Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KnQR1wbNzAbDdrowpQmWEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/all-that-sushi-chino-hills-2?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 468,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.9649334410726,
#    'longitude': -117.691224291666},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '15911 Pomona Rincon Rd',
#    'address2': 'Ste 130',
#    'address3': None,
#    'city': 'Chino Hills',
#    'zip_code': '91709',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['15911 Pomona Rincon Rd',
#     'Ste 130',
#     'Chino Hills, CA 91709']},
#   'phone': '+19096966174',
#   'display_phone': '(909) 696-6174',
#   'distance': 11940.547114134513},
#  {'id': 'L10JZKLrHDkJU0GR0rzmdA',
#   'alias': 'el-sushi-loco-pomona-pomona-5',
#   'name': 'El Sushi Loco - Pomona',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mEqGAET81rt6mf5BDlP5Pg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-sushi-loco-pomona-pomona-5?adjust_creative=7c6m2EFuzdcQsaqbzKeHUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7c6m2EFuzdcQsaqbzKeHUw',
#   'review_count': 232,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 34.061485, 'longitude': -117.775932},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1542 W Holt Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Pomona',
#    'zip_code': '91768',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1542 W Holt Ave', 'Pomona, CA 91768']},
#   'phone': '+19094690568',
#   'display_phone': '(909) 469-0568',
#   'distance': 2635.6235223953277}]

# %%
# How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   JlN5BhjbErkp6myx-8Adkw                             kazama-sushi-claremont
# 1   eh26nTBs70zvxlL8mFOq6g                          roll-to-go-sushi-pomona-3
# 2   v4mgrnnrqMCCEyLnzd5tgw                                spicy-fish-pomona-2
# 3   n49shr4AyXEdZHwrM-kjgQ                       kisetsu-restaurant-claremont
# 4   KCsnVV2LkHqNV7wu5r4FZw                heemo-sushi-chino-hills-chino-hills
# 5   ySzi-7ZESSMMteQQmHXHDA                          kaya-asian-cuisine-pomona
# 6   NjgpL_T9TmEHxWVv2-RH5A                              culichi-roll-pomona-3
# 7   4JWqfEnsDsRS3BeH0uyliw                         sushi-one-spot-montclair-3
# 8   CxVU-Pap9AVkHTSZGPOlAQ                               senor-sushi-pomona-2
# 9   bM61lLChoc5_5x2gyWXu4Q                              oni-sushi-claremont-2
# 10  5zqyjooZCmGJyYskNXlzhg               makomae-japanese-cuisine-diamond-bar
# 11  2C1-2Mj0xINqrtJQodq8OA                               show-sushi-san-dimas
# 12  8nTMRFSXn-NEu1NVAtRYiw                           j-sushi-and-ramen-pomona
# 13  Q5T7a_J09YX9IDOfcbGQlA                                sushiya-san-dimas-2
# 14  rxjJptHauUqFOZ4DWNmIZw  kaiba-japanese-ramen-sushi-and-grill-la-verne-...
# 15  u7QaCKPng22AsU3-w1qBgg                          sake-2-me-sushi-montclair
# 16  eKoLScfI41H7XmLXTDczPQ                                       imari-upland
# 17  cGRckOqyiJAPywwyCRwNOA                        rumble-fish-sushi-montclair
# 18  MyIvDxYoDwlIn8Nd_Fmp5w                       all-that-sushi-chino-hills-2
# 19  L10JZKLrHDkJU0GR0rzmdA                      el-sushi-loco-pomona-pomona-5
#
#                                               name  \
# 0                                     Kazama Sushi
# 1                                 Roll To Go Sushi
# 2                                       Spicy Fish
# 3                               Kisetsu Restaurant
# 4                          Heemo Sushi-Chino Hills
# 5                               Kaya Asian Cuisine
# 6                                     Culichi Roll
# 7                                   Sushi One Spot
# 8                                      Senor Sushi
# 9                                        Oni Sushi
# 10                        Makomae Japanese Cuisine
# 11                                      Show Sushi
# 12                                 J Sushi & Ramen
# 13                                         Sushiya
# 14  Kaiba Japanese Ramen, Sushi & Grill - La Verne
# 15                                 Sake 2 Me Sushi
# 16                                           Imari
# 17                               Rumble Fish Sushi
# 18                                  All That Sushi
# 19                          El Sushi Loco - Pomona
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/Rl8QJx...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/dVd3sW...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/3-fr-k...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/8hhBo3...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/hYBwPV...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/n43zul...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/3joqVy...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/fKiaLM...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/_AVDH_...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/uy9dxS...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/i9zO9n...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/ieaNBS...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/TuFKc3...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/V3qP37...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/2o54yY...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/tn_eVw...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/1Ia_Qi...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/dQXQkR...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/KnQR1w...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/mEqGAE...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/kazama-sushi-claremon...          1482
# 1   https://www.yelp.com/biz/roll-to-go-sushi-pomo...             2
# 2   https://www.yelp.com/biz/spicy-fish-pomona-2?a...           160
# 3   https://www.yelp.com/biz/kisetsu-restaurant-cl...            68
# 4   https://www.yelp.com/biz/heemo-sushi-chino-hil...           159
# 5   https://www.yelp.com/biz/kaya-asian-cuisine-po...           358
# 6   https://www.yelp.com/biz/culichi-roll-pomona-3...           272
# 7   https://www.yelp.com/biz/sushi-one-spot-montcl...           306
# 8   https://www.yelp.com/biz/senor-sushi-pomona-2?...           114
# 9   https://www.yelp.com/biz/oni-sushi-claremont-2...           328
# 10  https://www.yelp.com/biz/makomae-japanese-cuis...           681
# 11  https://www.yelp.com/biz/show-sushi-san-dimas?...          2509
# 12  https://www.yelp.com/biz/j-sushi-and-ramen-pom...           330
# 13  https://www.yelp.com/biz/sushiya-san-dimas-2?a...           258
# 14  https://www.yelp.com/biz/kaiba-japanese-ramen-...            79
# 15  https://www.yelp.com/biz/sake-2-me-sushi-montc...          1404
# 16  https://www.yelp.com/biz/imari-upland?adjust_c...           262
# 17  https://www.yelp.com/biz/rumble-fish-sushi-mon...          1166
# 18  https://www.yelp.com/biz/all-that-sushi-chino-...           468
# 19  https://www.yelp.com/biz/el-sushi-loco-pomona-...           232
#
#                                            categories  rating  \
# 0   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     5.0
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 3   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 4   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 5   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 6   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 8         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
# 9   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 10        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 11        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
# 12  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 13  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 14  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 15  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 16  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     5.0
# 17  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 18  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 19  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 34.095166, 'longitude': -117.719514}          [delivery]
# 1   {'latitude': 34.06199689430613, 'longitude': -...  [pickup, delivery]
# 2     {'latitude': 34.05437, 'longitude': -117.76271}          [delivery]
# 3   {'latitude': 34.1063217, 'longitude': -117.732...                  []
# 4   {'latitude': 34.01625920335954, 'longitude': -...                  []
# 5     {'latitude': 34.05398, 'longitude': -117.77543}  [pickup, delivery]
# 6   {'latitude': 34.06270300956817, 'longitude': -...  [pickup, delivery]
# 7   {'latitude': 34.083119, 'longitude': -117.696473}                  []
# 8   {'latitude': 34.0553180510785, 'longitude': -1...                  []
# 9     {'latitude': 34.09686, 'longitude': -117.71889}  [pickup, delivery]
# 10  {'latitude': 34.0344545348774, 'longitude': -1...          [delivery]
# 11  {'latitude': 34.108007, 'longitude': -117.826514}  [pickup, delivery]
# 12  {'latitude': 34.0280844704734, 'longitude': -1...          [delivery]
# 13    {'latitude': 34.10626, 'longitude': -117.81734}  [pickup, delivery]
# 14  {'latitude': 34.118826, 'longitude': -117.779561}  [pickup, delivery]
# 15  {'latitude': 34.063599, 'longitude': -117.681654}          [delivery]
# 16  {'latitude': 34.10765815493825, 'longitude': -...  [pickup, delivery]
# 17  {'latitude': 34.0888649, 'longitude': -117.685...  [pickup, delivery]
# 18  {'latitude': 33.9649334410726, 'longitude': -1...          [delivery]
# 19  {'latitude': 34.061485, 'longitude': -117.775932}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '101 N Indian Hill Blvd', 'addres...  +19094502505
# 1    NaN  {'address1': '642 E Holt Ave', 'address2': '',...  +16264782188
# 2      $  {'address1': '1084 W Mission Blvd', 'address2'...  +19097668254
# 3    $$$  {'address1': '950 W Foothill Blvd', 'address2'...  +19096256250
# 4     $$  {'address1': '12959 Peyton Dr', 'address2': No...  +19092229331
# 5     $$  {'address1': '1640 W Mission Blvd', 'address2'...  +19096222689
# 6     $$  {'address1': '171 E Holt Ave', 'address2': 'St...  +19097668006
# 7     $$  {'address1': '9405 Monte Vista Ave', 'address2...  +19096260070
# 8     $$  {'address1': '101 W Mission Blvd', 'address2':...  +19094616412
# 9     $$  {'address1': '300 N Indian Hill Blvd', 'addres...  +19096212772
# 10    $$  {'address1': '868 N Diamond Bar Blvd', 'addres...  +19098616537
# 11   $$$  {'address1': '957 W Arrow Hwy', 'address2': ''...  +19095922911
# 12    $$  {'address1': '18 Rancho Camino Dr', 'address2'...  +19096228700
# 13    $$  {'address1': '536 W Bonita Ave', 'address2': '...  +19095997833
# 14    $$  {'address1': '1263 Foothill Blvd', 'address2':...  +19095961111
# 15    $$  {'address1': '5660 Holt Blvd', 'address2': '',...  +19096260113
# 16    $$  {'address1': '733 W Foothill Blvd', 'address2'...  +19099311975
# 17    $$  {'address1': '5470 Moreno St', 'address2': 'St...  +19099461119
# 18    $$  {'address1': '15911 Pomona Rincon Rd', 'addres...  +19096966174
# 19    $$  {'address1': '1542 W Holt Ave', 'address2': ''...  +19094690568
#
#      display_phone      distance
# 0   (909) 450-2505   4516.914865
# 1   (626) 478-2188    844.554815
# 2   (909) 766-8254   1634.369337
# 3   (909) 625-6250   5134.577940
# 4   (909) 222-9331   5058.071402
# 5   (909) 622-2689   2859.324205
# 6   (909) 766-8006    150.753304
# 7   (909) 626-0070   5255.515530
# 8   (909) 461-6412    766.212414
# 9   (909) 621-2772   4686.277205
# 10  (909) 861-6537   6194.288135
# 11  (909) 592-2911   8924.625168
# 12  (909) 622-8700   3912.437983
# 13  (909) 599-7833   8127.811177
# 14  (909) 596-1111   7007.803149
# 15  (909) 626-0113   6054.841839
# 16  (909) 931-1975   9522.221469
# 17  (909) 946-1119   6480.223082
# 18  (909) 696-6174  11940.547114
# 19  (909) 469-0568   2635.623522

# %% [markdown]
# * Where is the actual data we want to save?

# %%
# How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# * Calculate how many pages of results needed to cover the total_results

# %%
(results['total'])/results_per_page
# Out:
# 27.4

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/results_per_page)
n_pages
# Out:
# 28

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    # The block of code we want to TRY to run
    try:

        

        time.sleep(.2)


    
        # Read in results in progress file and check the length
        with open (JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        # Save number of results for to use as offset
        n_results = len(previous_results)
        
        
        # Use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        # Append new results and save to file
        previous_results.extend(results['businesses'])

        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)



            
    # What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %% [markdown]
# ## <u>Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                alias  \
# 0  eh26nTBs70zvxlL8mFOq6g            roll-to-go-sushi-pomona-3
# 1  v4mgrnnrqMCCEyLnzd5tgw                  spicy-fish-pomona-2
# 2  n49shr4AyXEdZHwrM-kjgQ         kisetsu-restaurant-claremont
# 3  KCsnVV2LkHqNV7wu5r4FZw  heemo-sushi-chino-hills-chino-hills
# 4  ySzi-7ZESSMMteQQmHXHDA            kaya-asian-cuisine-pomona
#
#                       name                                          image_url  \
# 0         Roll To Go Sushi  https://s3-media2.fl.yelpcdn.com/bphoto/dVd3sW...
# 1               Spicy Fish  https://s3-media2.fl.yelpcdn.com/bphoto/3-fr-k...
# 2       Kisetsu Restaurant  https://s3-media3.fl.yelpcdn.com/bphoto/8hhBo3...
# 3  Heemo Sushi-Chino Hills  https://s3-media2.fl.yelpcdn.com/bphoto/hYBwPV...
# 4       Kaya Asian Cuisine  https://s3-media2.fl.yelpcdn.com/bphoto/n43zul...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/roll-to-go-sushi-pomo...             2
# 1      False  https://www.yelp.com/biz/spicy-fish-pomona-2?a...           160
# 2      False  https://www.yelp.com/biz/kisetsu-restaurant-cl...            68
# 3      False  https://www.yelp.com/biz/heemo-sushi-chino-hil...           159
# 4      False  https://www.yelp.com/biz/kaya-asian-cuisine-po...           358
#
#                                           categories  rating  \
# 0        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     5.0
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 3  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 4  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 34.06199689430613, 'longitude': -...  [delivery, pickup]
# 1    {'latitude': 34.05437, 'longitude': -117.76271}          [delivery]
# 2  {'latitude': 34.1063217, 'longitude': -117.732...                  []
# 3  {'latitude': 34.01625920335954, 'longitude': -...                  []
# 4    {'latitude': 34.05398, 'longitude': -117.77543}  [delivery, pickup]
#
#                                             location         phone  \
# 0  {'address1': '642 E Holt Ave', 'address2': '',...  +16264782188
# 1  {'address1': '1084 W Mission Blvd', 'address2'...  +19097668254
# 2  {'address1': '950 W Foothill Blvd', 'address2'...  +19096256250
# 3  {'address1': '12959 Peyton Dr', 'address2': No...  +19092229331
# 4  {'address1': '1640 W Mission Blvd', 'address2'...  +19096222689
#
#     display_phone     distance price
# 0  (626) 478-2188   844.554815   NaN
# 1  (909) 766-8254  1634.369337     $
# 2  (909) 625-6250  5134.577940   $$$
# 3  (909) 222-9331  5058.071402    $$
# 4  (909) 622-2689  2859.324205    $$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             547 non-null    object
#  1   alias          547 non-null    object
#  2   name           547 non-null    object
#  3   image_url      547 non-null    object
#  4   is_closed      547 non-null    bool
#  5   url            547 non-null    object
#  6   review_count   547 non-null    int64
#  7   categories     547 non-null    object
#  8   rating         547 non-null    float64
#  9   coordinates    547 non-null    object
#  10  transactions   547 non-null    object
#  11  location       547 non-null    object
#  12  phone          547 non-null    object
#  13  display_phone  547 non-null    object
#  14  distance       547 non-null    float64
#  15  price          492 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 64.8+ KB

# %%
# convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Phillips Ranch-sushi.csv.gz'

# %%
# Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# ## Compare filesize with os module's os.path.getsize

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 542,424 Bytes
# CSV.GZ FILE: 80,203 Bytes
# the csv.gz is 6.7631385359649885 times smaller!
